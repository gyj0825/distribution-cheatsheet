# %% [markdown]
# # 均匀分布（Uniform Distribution）
# ***
# ## 定义
# 对于投骰子来说, 结果是1到6，得到任何一个结果的概率是相同的，这就是均匀分布的基础。与伯努利分布不同，均匀分布的多有可能结果的n个数也是相等的。
# 如果变量X是均匀分布的，则密度函数可以表示为：
# $$ f(x) = \frac{1}{b-a}     a < x < b $$
#
# 均匀分布的曲线是这样的：
# ![Screenshot 2023-07-04 at 23.36.53.png](attachment:a87b337f-f788-46be-b9c1-cf03c1fff729.png)
# 可以看到，均匀分布曲线的形状是一个矩形，这也是均匀分布又称为矩形分布的原因。其中，a和b是参数。
# 花店每天销售的花束数量是均匀分布的，最多为40，最少为10。我们来计算下日销量在15到30之间的概率。
# 日销售在15到30之间的概率为 (30-15)*(1/(40-10)) = 0.5.
# 同样的，日销量大于20的概率为 0.667.

# %% [markdown]
# numpy实现待完成
